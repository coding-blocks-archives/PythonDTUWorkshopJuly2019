# %%
# !wget https://www.dropbox.com/s/5o64ru428jlb29g/haarcascade_frontalface_alt.xml?dl=0
# Out:
# --2019-07-23 08:53:20--  https://www.dropbox.com/s/5o64ru428jlb29g/haarcascade_frontalface_alt.xml?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:601f:1::a27d:901
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/5o64ru428jlb29g/haarcascade_frontalface_alt.xml [following]
# --2019-07-23 08:53:20--  https://www.dropbox.com/s/raw/5o64ru428jlb29g/haarcascade_frontalface_alt.xml
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf4a767a081a4f63ac0ee0ad0ea.dl.dropboxusercontent.com/cd/0/inline/AlMjH3L7khkkG1BffMBacQot4ScL_8Z53gCUdRK89gw13sGvtOIrubWudIqtiZqtplx4iF9-0SP0XLUzvtG1xykJyPtUMcDNsVvnvxAZat8S8Q/file# [following]
# --2019-07-23 08:53:20--  https://ucf4a767a081a4f63ac0ee0ad0ea.dl.dropboxusercontent.com/cd/0/inline/AlMjH3L7khkkG1BffMBacQot4ScL_8Z53gCUdRK89gw13sGvtOIrubWudIqtiZqtplx4iF9-0SP0XLUzvtG1xykJyPtUMcDNsVvnvxAZat8S8Q/file
# Resolving ucf4a767a081a4f63ac0ee0ad0ea.dl.dropboxusercontent.com (ucf4a767a081a4f63ac0ee0ad0ea.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to ucf4a767a081a4f63ac0ee0ad0ea.dl.dropboxusercontent.com (ucf4a767a081a4f63ac0ee0ad0ea.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 701059 (685K) [text/plain]
# Saving to: ‘haarcascade_frontalface_alt.xml?dl=0’
#
# haarcascade_frontal 100%[===================>] 684.63K  --.-KB/s    in 0.09s
#
# 2019-07-23 08:53:21 (7.11 MB/s) - ‘haarcascade_frontalface_alt.xml?dl=0’ saved [701059/701059]

# %%
# !ls
# Out:
#  download.jpg  'haarcascade_frontalface_alt.xml?dl=0'   sample_data

# %%
#from google.colab import files
#files.upload()

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('image.jpg')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7F96FC414B38>

# %%
# !ls
# Out:
#  Before.png    'haarcascade_frontalface_alt.xml?dl=0'
#  download.jpg   sample_data

# %%
# !mv haarcascade_frontalface_alt.xml?dl=0 my_model.xml

# %%
# !ls
# Out:
# Before.png  download.jpg  my_model.xml	sample_data

# %%
face_detector = cv2.CascadeClassifier('my_model.xml')

# %%
faces_detected = face_detector.detectMultiScale(img,1.3,5)
print(faces_detected)
# Out:
# [[266 253  57  57]
#  [400 250  55  55]
#  [501 250  59  59]
#  [791 258  60  60]
#  [667 266  50  50]
#  [153 269  57  57]]

# %%
for face in faces_detected:
    
    x,y,w,h = face
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,255,0),2)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640 at 0x7F96FC1A0C50>
